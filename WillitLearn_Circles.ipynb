# %%
from fastai.vision import *

# %%
import torch

nums = torch.randn(2,2)
nums.cuda()
# Out:
# tensor([[ 0.2789,  0.4872],
#         [-0.1485,  0.7083]], device='cuda:0')

# %%
datapath = Path('data/WillItLearn_Circles')

# %%
#!rm -rf  data/WillItLearn_Circles/models
#ls data/WillItLearn_Circles/

# %%
#tfms = get_transforms(do_flip=False)

# %%
bs = 64

# %%
data = (ImageDataBunch.from_folder(datapath,valid_pct=0.1))
                #.transform(tfms, size=32))

# %%
data.show_batch(rows=3, figsize=(7,6))

# %%
data.c
# Out:
# 10

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(4)
# Out:
# Total time: 02:16 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>1.533995</th>
#     <th>1.170380</th>
#     <th>0.495000</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>1.156324</th>
#     <th>0.955834</th>
#     <th>0.422000</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>1.004632</th>
#     <th>0.876000</th>
#     <th>0.386000</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.884753</th>
#     <th>0.868020</th>
#     <th>0.380000</th>
#   </tr>
# </table>

# %%
learn.save('mini_train')

# %%
learn.show_results()

# %%
learn.show_results(ds_type=DatasetType.Train, rows=4, figsize=(8,10))
